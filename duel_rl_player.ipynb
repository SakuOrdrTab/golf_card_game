# %% [markdown]
# ## Test RL agent against different opponents

# %%
from src.game import Game
import pandas as pd

# %% [markdown]
# Different player types:
# "Stupid...", "RL Agent...", "Comput...", "Advanc...", "Human..."

# %%
BENCHMARK_PLAYER_DESC = "Stupid player"

# %% [markdown]
# Other constants

# %%
ITERATIONS = 100

# %% [markdown]
# Run test rounds

# %%
results = pd.DataFrame(columns=['winner', 'turns', BENCHMARK_PLAYER_DESC + " winner"])
for i in range(ITERATIONS):

    # Remember to set correct player type here, too
    game = Game(2, 
                human_player=False, 
                silent_mode=False, 
                stupid_player=True,
                advanced_player=False,
                rl_player=True)
    turns, score_dict, winner = game.play_game()
    benchmark_row = winner.startswith(BENCHMARK_PLAYER_DESC[:6])
    new_row = pd.DataFrame(
        {
            'winner': [winner], 
            'turns': [turns], 
            BENCHMARK_PLAYER_DESC + " winner": [benchmark_row]
        }
    )
    results = pd.concat([results, new_row], ignore_index=True)

print("Turns quartiles:")
quartiles = results['turns'].quantile([0.25, 0.5, 0.75, 1.0])
print(quartiles)
print(f"{BENCHMARK_PLAYER_DESC} winning percentage: {results[BENCHMARK_PLAYER_DESC + " winner"].mean() * 100}")
# Out:
# RL Agent 637 turns the initial cards visible.
# StupidMc Birdbucket 1.3 turns the initial cards visible.
# Players shuffled, player StupidMc Birdbucket 1.3 starts...
# Complete init
# ------------
# Turn 1:
# StupidMc Birdbucket 1.3 draws ♧3 from the played deck.
# ♧3 is placed in the played deck by StupidMc Birdbucket 1.3.
# [DEBUG] table card values:  [4, 5, 8]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 637 draws ♧3 from the played deck.
# RL Agent 637 puts ♧3 on the table at 2. row, 2. place
# ♧4 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 2:
# StupidMc Birdbucket 1.3 draws ♧4 from the played deck.
# StupidMc Birdbucket 1.3 puts ♧4 on the table at 0. row, 1. place
# ♧1 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 3, 8]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 144 total: 145 res: False
# RL Agent 637 draws ♧1 from the played deck.
# RL Agent 637 puts ♧1 on the table at 2. row, 2. place
# ♧3 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 3:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♢4 on the table at 1. row, 1. place
# ♢2 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 1, 8]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 637 draws ♢2 from the played deck.
# RL Agent 637 puts ♢2 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 4:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♡10 on the table at 0. row, 2. place
# ♤5 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 2, 8]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 637 draws ♤5 from the played deck.
# RL Agent 637 puts ♤5 on the table at 2. row, 2. place
# ♢2 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 5:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♧11 on the table at 1. row, 2. place
# ♤7 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 5, 8]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 637 draws ♤7 from the played deck.
# RL Agent 637 puts ♤7 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 6:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♧0 on the table at 1. row, 1. place
# ♢4 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 7, 8]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 637 draws ♢4 from the played deck.
# RL Agent 637 puts ♢4 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 7:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♧12 on the table at 0. row, 1. place
# ♧4 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 4, 8]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 637 draws ♧4 from the played deck.
# RL Agent 637 puts ♧4 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 8:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♧10 on the table at 2. row, 3. place
# ♡3 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 4, 8]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 637 draws ♡3 from the played deck.
# RL Agent 637 puts ♡3 on the table at 2. row, 2. place
# ♧4 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 9:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♤1 on the table at 1. row, 3. place
# ♢1 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 3, 8]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 144 total: 145 res: False
# RL Agent 637 draws ♢1 from the played deck.
# RL Agent 637 puts ♢1 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 10:
# StupidMc Birdbucket 1.3 draws from the drawing deck.
# StupidMc Birdbucket 1.3 puts ♢7 on the table at 1. row, 3. place
# ♤1 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 1, 8]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 144 total: 145 res: False
# RL Agent 637 draws ♤1 from the played deck.
# RL Agent 637 puts ♤1 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by RL Agent 637
# ------------
# Turn 11:
# StupidMc Birdbucket 1.3 draws ♢1 from the played deck.
# StupidMc Birdbucket 1.3 puts ♢1 on the table at 2. row, 1. place
# ♧7 is placed on the played deck from the table by StupidMc Birdbucket 1.3
# [DEBUG] table card values:  [4, 5, 1, 8]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: True
# RL Agent 637 draws from the drawing deck.
# RL Agent 637 puts ♤2 on the table at 2. row, 2. place
# ♤1 is placed on the played deck from the table by RL Agent 637
# Game over in 11 rounds!
# Scores:
# StupidMc Birdbucket 1.3: 67
# RL Agent 637: 38
# RL Agent 6515 turns the initial cards visible.
# StupidKommodore K64 1.1 turns the initial cards visible.
# Players shuffled, player StupidKommodore K64 1.1 starts...
# Complete init
# ------------
# Turn 1:
# StupidKommodore K64 1.1 draws ♧4 from the played deck.
# StupidKommodore K64 1.1 puts ♧4 on the table at 2. row, 3. place
# ♢12 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 9, 9]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 100 played_inc: 1 total: 101 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♧1 on the table at 2. row, 2. place
# ♧3 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 2:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♤0 on the table at 1. row, 3. place
# ♡3 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 1, 9, 9]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 6515 draws ♡3 from the played deck.
# RL Agent 6515 puts ♡3 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 3:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♤10 on the table at 0. row, 3. place
# ♤8 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 3, 9, 9]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 6515 draws ♤8 from the played deck.
# RL Agent 6515 puts ♤8 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 4:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♢4 on the table at 2. row, 1. place
# ♧11 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 8, 9, 9]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♡0 on the table at 2. row, 2. place
# ♤8 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 5:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♢8 on the table at 2. row, 1. place
# ♢4 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 0, 9, 9]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 6515 draws ♢4 from the played deck.
# RL Agent 6515 puts ♢4 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 6:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♤2 on the table at 0. row, 2. place
# ♢0 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 4, 9, 9]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 256 total: 257 res: False
# RL Agent 6515 draws ♢0 from the played deck.
# RL Agent 6515 puts ♢0 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 7:
# StupidKommodore K64 1.1 draws ♢4 from the played deck.
# StupidKommodore K64 1.1 puts ♢4 on the table at 0. row, 3. place
# ♤10 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 0, 9, 9]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 16 played_inc: 1 total: 17 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♢11 on the table at 2. row, 2. place
# ♢0 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 8:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♤1 on the table at 0. row, 3. place
# ♢4 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 11, 9, 9]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 6515 draws ♢4 from the played deck.
# RL Agent 6515 puts ♢4 on the table at 2. row, 2. place
# ♢11 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 9:
# StupidKommodore K64 1.1 draws ♢11 from the played deck.
# StupidKommodore K64 1.1 puts ♢11 on the table at 0. row, 3. place
# ♤1 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 4, 9, 9]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 6515 draws ♤1 from the played deck.
# RL Agent 6515 puts ♤1 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 10:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♡4 on the table at 0. row, 3. place
# ♢11 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 1, 9, 9]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♤11 on the table at 2. row, 2. place
# ♤1 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 11:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♡10 on the table at 2. row, 2. place
# ♧12 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 11, 9, 9]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 64 played_inc: 1 total: 65 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♢10 on the table at 2. row, 2. place
# ♤11 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 12:
# StupidKommodore K64 1.1 draws ♤11 from the played deck.
# ♤11 is placed in the played deck by StupidKommodore K64 1.1.
# [DEBUG] table card values:  [0, 10, 9, 9]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 36 played_inc: 1 total: 37 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♢1 on the table at 2. row, 2. place
# ♢10 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 13:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♡2 on the table at 1. row, 1. place
# ♧9 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 1, 9, 9]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 1 total: 2 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♢7 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 14:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♢2 on the table at 1. row, 3. place
# ♤0 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 7, 9, 9]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 256 total: 257 res: False
# RL Agent 6515 draws ♤0 from the played deck.
# RL Agent 6515 puts ♤0 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 15:
# StupidKommodore K64 1.1 draws ♢7 from the played deck.
# StupidKommodore K64 1.1 puts ♢7 on the table at 2. row, 2. place
# ♡10 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 0, 9, 9]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 16 played_inc: 1 total: 17 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♡12 on the table at 2. row, 2. place
# ♤0 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 16:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♤7 on the table at 1. row, 1. place
# ♡2 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 12, 9, 9]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 6515 draws ♡2 from the played deck.
# RL Agent 6515 puts ♡2 on the table at 2. row, 2. place
# ♡12 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 17:
# StupidKommodore K64 1.1 draws ♡12 from the played deck.
# StupidKommodore K64 1.1 puts ♡12 on the table at 0. row, 3. place
# ♡4 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 2, 9, 9]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 6515 draws ♡4 from the played deck.
# RL Agent 6515 puts ♡4 on the table at 2. row, 2. place
# ♡2 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 18:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♤6 on the table at 2. row, 1. place
# ♢8 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 4, 9, 9]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 6515 draws ♢8 from the played deck.
# RL Agent 6515 puts ♢8 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 19:
# StupidKommodore K64 1.1 draws ♡4 from the played deck.
# StupidKommodore K64 1.1 puts ♡4 on the table at 2. row, 1. place
# ♤6 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 8, 9, 9]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6515 draws ♤6 from the played deck.
# RL Agent 6515 puts ♤6 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 20:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♧5 on the table at 0. row, 1. place
# ♤5 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 6, 9, 9]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 6515 draws ♤5 from the played deck.
# RL Agent 6515 puts ♤5 on the table at 2. row, 2. place
# ♤6 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 21:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♡6 on the table at 0. row, 3. place
# ♡12 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 5, 9, 9]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 100 played_inc: 1 total: 101 res: True
# RL Agent 6515 draws from the drawing deck.
# RL Agent 6515 puts ♡8 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 22:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♡7 on the table at 0. row, 2. place
# ♤2 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 8, 9, 9]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 6515 draws ♤2 from the played deck.
# RL Agent 6515 puts ♤2 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 23:
# StupidKommodore K64 1.1 draws from the drawing deck.
# StupidKommodore K64 1.1 puts ♧10 on the table at 0. row, 3. place
# ♡6 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 2, 9, 9]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6515 draws ♡6 from the played deck.
# RL Agent 6515 puts ♡6 on the table at 2. row, 2. place
# ♤2 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 24:
# StupidKommodore K64 1.1 draws ♤2 from the played deck.
# StupidKommodore K64 1.1 puts ♤2 on the table at 1. row, 1. place
# ♤7 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 6, 9, 9]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 6515 draws ♤7 from the played deck.
# RL Agent 6515 puts ♤7 on the table at 2. row, 2. place
# ♡6 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 25:
# StupidKommodore K64 1.1 draws ♡6 from the played deck.
# StupidKommodore K64 1.1 puts ♡6 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 7, 9, 9]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 6515 draws ♢7 from the played deck.
# RL Agent 6515 puts ♢7 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 6515
# ------------
# Turn 26:
# StupidKommodore K64 1.1 draws ♤7 from the played deck.
# StupidKommodore K64 1.1 puts ♤7 on the table at 1. row, 2. place
# ♧2 is placed on the played deck from the table by StupidKommodore K64 1.1
# [DEBUG] table card values:  [0, 7, 9, 9]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 6515 draws ♧2 from the played deck.
# RL Agent 6515 puts ♧2 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 6515
# Game over in 26 rounds!
# Scores:
# StupidKommodore K64 1.1: 47
# RL Agent 6515: 45
# RL Agent 356 turns the initial cards visible.
# StupidVictor-20 2.6 turns the initial cards visible.
# Players shuffled, player RL Agent 356 starts...
# Complete init
# ------------
# Turn 1:
# [DEBUG] table card values:  [0, 12, 3]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 356 draws ♧6 from the played deck.
# RL Agent 356 puts ♧6 on the table at 2. row, 2. place
# ♡12 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♡12 from the played deck.
# StupidVictor-20 2.6 puts ♡12 on the table at 2. row, 1. place
# ♧7 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 2:
# [DEBUG] table card values:  [0, 6, 3]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: False
# RL Agent 356 draws ♧7 from the played deck.
# RL Agent 356 puts ♧7 on the table at 2. row, 2. place
# ♧6 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws from the drawing deck.
# StupidVictor-20 2.6 puts ♢0 on the table at 1. row, 2. place
# ♤11 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 3:
# [DEBUG] table card values:  [0, 7, 3]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 81 played_inc: 1 total: 82 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♧11 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♧7 from the played deck.
# StupidVictor-20 2.6 puts ♧7 on the table at 1. row, 1. place
# ♤10 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 4:
# [DEBUG] table card values:  [0, 11, 3]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 4 total: 13 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♧2 on the table at 2. row, 2. place
# ♧11 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws from the drawing deck.
# StupidVictor-20 2.6 puts ♡11 on the table at 1. row, 3. place
# ♤9 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 5:
# [DEBUG] table card values:  [0, 2, 3]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♧4 on the table at 2. row, 2. place
# ♧2 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws from the drawing deck.
# StupidVictor-20 2.6 puts ♢1 on the table at 0. row, 2. place
# ♡0 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 6:
# [DEBUG] table card values:  [0, 4, 3]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 121 total: 122 res: False
# RL Agent 356 draws ♡0 from the played deck.
# RL Agent 356 puts ♡0 on the table at 2. row, 2. place
# ♧4 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♧4 from the played deck.
# StupidVictor-20 2.6 puts ♧4 on the table at 0. row, 1. place
# ♧10 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 7:
# [DEBUG] table card values:  [0, 0, 3]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 100 played_inc: 1 total: 101 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♧9 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♡0 from the played deck.
# StupidVictor-20 2.6 puts ♡0 on the table at 0. row, 1. place
# ♧4 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 8:
# [DEBUG] table card values:  [0, 9, 3]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 356 draws ♧4 from the played deck.
# RL Agent 356 puts ♧4 on the table at 2. row, 2. place
# ♧9 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws from the drawing deck.
# StupidVictor-20 2.6 puts ♧1 on the table at 1. row, 1. place
# ♧7 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 9:
# [DEBUG] table card values:  [0, 4, 3]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 16 played_inc: 1 total: 17 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♢4 on the table at 2. row, 2. place
# ♧4 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♧4 from the played deck.
# StupidVictor-20 2.6 puts ♧4 on the table at 2. row, 3. place
# ♢9 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 10:
# [DEBUG] table card values:  [0, 4, 3]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 36 played_inc: 1 total: 37 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♤12 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws from the drawing deck.
# StupidVictor-20 2.6 puts ♢2 on the table at 2. row, 3. place
# ♧4 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 11:
# [DEBUG] table card values:  [0, 12, 3]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 356 draws ♧4 from the played deck.
# RL Agent 356 puts ♧4 on the table at 2. row, 2. place
# ♤12 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♤12 from the played deck.
# StupidVictor-20 2.6 puts ♤12 on the table at 0. row, 1. place
# ♡0 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 12:
# [DEBUG] table card values:  [0, 4, 3]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 121 total: 122 res: False
# RL Agent 356 draws ♡0 from the played deck.
# RL Agent 356 puts ♡0 on the table at 2. row, 2. place
# ♧4 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♧4 from the played deck.
# ♧4 is placed in the played deck by StupidVictor-20 2.6.
# ------------
# Turn 13:
# [DEBUG] table card values:  [0, 0, 3]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: True
# RL Agent 356 draws from the drawing deck.
# RL Agent 356 puts ♡8 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♡0 from the played deck.
# StupidVictor-20 2.6 puts ♡0 on the table at 2. row, 3. place
# ♢2 is placed on the played deck from the table by StupidVictor-20 2.6
# ------------
# Turn 14:
# [DEBUG] table card values:  [0, 8, 3]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 356 draws ♢2 from the played deck.
# RL Agent 356 puts ♢2 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 356
# StupidVictor-20 2.6 draws ♡8 from the played deck.
# StupidVictor-20 2.6 puts ♡8 on the table at 0. row, 3. place
# ♤4 is placed on the played deck from the table by StupidVictor-20 2.6
# Game over in 14 rounds!
# Scores:
# RL Agent 356: 38
# StupidVictor-20 2.6: 53
# RL Agent 3182 turns the initial cards visible.
# StupidZinclair XZ 3.6 turns the initial cards visible.
# Players shuffled, player RL Agent 3182 starts...
# Complete init
# ------------
# Turn 1:
# [DEBUG] table card values:  [5, 11, 4]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 324 total: 325 res: False
# RL Agent 3182 draws ♧0 from the played deck.
# RL Agent 3182 puts ♧0 on the table at 2. row, 2. place
# ♤11 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♤11 from the played deck.
# StupidZinclair XZ 3.6 puts ♤11 on the table at 1. row, 1. place
# ♢9 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 2:
# [DEBUG] table card values:  [5, 0, 4]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 1 total: 26 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♡8 on the table at 2. row, 2. place
# ♧0 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♧0 from the played deck.
# StupidZinclair XZ 3.6 puts ♧0 on the table at 0. row, 2. place
# ♧7 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 3:
# [DEBUG] table card values:  [5, 8, 4]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 3182 draws ♧7 from the played deck.
# RL Agent 3182 puts ♧7 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♡8 from the played deck.
# StupidZinclair XZ 3.6 puts ♡8 on the table at 0. row, 2. place
# ♧0 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 4:
# [DEBUG] table card values:  [5, 7, 4]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 196 total: 197 res: False
# RL Agent 3182 draws ♧0 from the played deck.
# RL Agent 3182 puts ♧0 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♧7 from the played deck.
# StupidZinclair XZ 3.6 puts ♧7 on the table at 2. row, 1. place
# ♤6 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 5:
# [DEBUG] table card values:  [5, 0, 4]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♤12 on the table at 2. row, 2. place
# ♧0 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♢11 on the table at 1. row, 3. place
# ♢3 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 6:
# [DEBUG] table card values:  [5, 12, 4]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 3182 draws ♢3 from the played deck.
# RL Agent 3182 puts ♢3 on the table at 2. row, 2. place
# ♤12 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♤12 from the played deck.
# StupidZinclair XZ 3.6 puts ♤12 on the table at 1. row, 1. place
# ♤11 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 7:
# [DEBUG] table card values:  [5, 3, 4]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 121 played_inc: 1 total: 122 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♡0 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♢3 from the played deck.
# ♢3 is placed in the played deck by StupidZinclair XZ 3.6.
# ------------
# Turn 8:
# [DEBUG] table card values:  [5, 0, 4]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 3182 draws ♢3 from the played deck.
# RL Agent 3182 puts ♢3 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♡0 from the played deck.
# StupidZinclair XZ 3.6 puts ♡0 on the table at 1. row, 2. place
# ♧1 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 9:
# [DEBUG] table card values:  [5, 3, 4]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 3182 draws ♧1 from the played deck.
# RL Agent 3182 puts ♧1 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♧5 on the table at 0. row, 1. place
# ♤0 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 10:
# [DEBUG] table card values:  [5, 1, 4]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 144 total: 145 res: False
# RL Agent 3182 draws ♤0 from the played deck.
# RL Agent 3182 puts ♤0 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♡2 on the table at 0. row, 3. place
# ♤9 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 11:
# [DEBUG] table card values:  [5, 0, 4]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 1 total: 26 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♡9 on the table at 2. row, 2. place
# ♤0 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♧2 on the table at 1. row, 1. place
# ♤12 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 12:
# [DEBUG] table card values:  [5, 9, 4]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 100 played_inc: 1 total: 101 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♧8 on the table at 2. row, 2. place
# ♡9 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♢2 on the table at 1. row, 1. place
# ♧2 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 13:
# [DEBUG] table card values:  [5, 8, 4]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 3182 draws ♧2 from the played deck.
# RL Agent 3182 puts ♧2 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♢5 on the table at 1. row, 2. place
# ♡0 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 14:
# [DEBUG] table card values:  [5, 2, 4]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 144 total: 145 res: False
# RL Agent 3182 draws ♡0 from the played deck.
# RL Agent 3182 puts ♡0 on the table at 2. row, 2. place
# ♧2 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♢10 on the table at 2. row, 1. place
# ♧7 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 15:
# [DEBUG] table card values:  [5, 0, 4]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 1 total: 10 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♡4 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♢0 on the table at 2. row, 2. place
# ♤10 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 16:
# [DEBUG] table card values:  [5, 4, 4]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 64 played_inc: 1 total: 65 res: True
# RL Agent 3182 draws from the drawing deck.
# RL Agent 3182 puts ♡12 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♡4 from the played deck.
# StupidZinclair XZ 3.6 puts ♡4 on the table at 0. row, 1. place
# ♧5 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 17:
# [DEBUG] table card values:  [5, 12, 4]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 3182 draws ♧5 from the played deck.
# RL Agent 3182 puts ♧5 on the table at 2. row, 2. place
# ♡12 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws from the drawing deck.
# StupidZinclair XZ 3.6 puts ♡11 on the table at 0. row, 1. place
# ♡4 is placed on the played deck from the table by StupidZinclair XZ 3.6
# ------------
# Turn 18:
# [DEBUG] table card values:  [5, 5, 4]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 3182 draws ♡4 from the played deck.
# RL Agent 3182 puts ♡4 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♧5 from the played deck.
# ♧5 is placed in the played deck by StupidZinclair XZ 3.6.
# ------------
# Turn 19:
# [DEBUG] table card values:  [5, 4, 4]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 1 total: 2 res: False
# RL Agent 3182 draws ♧5 from the played deck.
# RL Agent 3182 puts ♧5 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by RL Agent 3182
# StupidZinclair XZ 3.6 draws ♡4 from the played deck.
# StupidZinclair XZ 3.6 puts ♡4 on the table at 2. row, 3. place
# ♤2 is placed on the played deck from the table by StupidZinclair XZ 3.6
# Game over in 19 rounds!
# Scores:
# RL Agent 3182: 43
# StupidZinclair XZ 3.6: 53
# RL Agent 4470 turns the initial cards visible.
# StupidVictor-20 2.5 turns the initial cards visible.
# Players shuffled, player RL Agent 4470 starts...
# Complete init
# ------------
# Turn 1:
# [DEBUG] table card values:  [0, 10, 12]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 4470 draws ♧6 from the played deck.
# RL Agent 4470 puts ♧6 on the table at 2. row, 2. place
# ♢11 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♧8 on the table at 2. row, 2. place
# ♢2 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 2:
# [DEBUG] table card values:  [0, 6, 10, 12]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 4470 draws ♢2 from the played deck.
# RL Agent 4470 puts ♢2 on the table at 2. row, 2. place
# ♧6 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# ♢8 is placed in the played deck by StupidVictor-20 2.5.
# ------------
# Turn 3:
# [DEBUG] table card values:  [0, 2, 10, 12]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 4470 draws ♢8 from the played deck.
# RL Agent 4470 puts ♢8 on the table at 2. row, 2. place
# ♢2 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♡8 on the table at 1. row, 3. place
# ♢5 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 4:
# [DEBUG] table card values:  [0, 8, 10, 12]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 4470 draws ♢5 from the played deck.
# RL Agent 4470 puts ♢5 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♡10 on the table at 0. row, 3. place
# ♢7 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 5:
# [DEBUG] table card values:  [0, 5, 10, 12]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 4470 draws ♢7 from the played deck.
# RL Agent 4470 puts ♢7 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♢5 from the played deck.
# StupidVictor-20 2.5 puts ♢5 on the table at 2. row, 3. place
# ♤9 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 6:
# [DEBUG] table card values:  [0, 7, 10, 12]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 4470 draws ♤9 from the played deck.
# RL Agent 4470 puts ♤9 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♧7 on the table at 1. row, 3. place
# ♡8 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 7:
# [DEBUG] table card values:  [0, 9, 10, 12]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 4470 draws ♡8 from the played deck.
# RL Agent 4470 puts ♡8 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♤9 from the played deck.
# StupidVictor-20 2.5 puts ♤9 on the table at 2. row, 1. place
# ♤3 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 8:
# [DEBUG] table card values:  [0, 8, 10, 12]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 4470 draws ♤3 from the played deck.
# RL Agent 4470 puts ♤3 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♡8 from the played deck.
# StupidVictor-20 2.5 puts ♡8 on the table at 0. row, 1. place
# ♡11 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 9:
# [DEBUG] table card values:  [0, 3, 10, 12]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: True
# RL Agent 4470 draws from the drawing deck.
# RL Agent 4470 puts ♤4 on the table at 2. row, 2. place
# ♤3 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♤12 on the table at 0. row, 1. place
# ♡8 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 10:
# [DEBUG] table card values:  [0, 4, 10, 12]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 4470 draws ♡8 from the played deck.
# RL Agent 4470 puts ♡8 on the table at 2. row, 2. place
# ♤4 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♤4 from the played deck.
# StupidVictor-20 2.5 puts ♤4 on the table at 1. row, 3. place
# ♧7 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 11:
# [DEBUG] table card values:  [0, 8, 10, 12]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 4470 draws ♧7 from the played deck.
# RL Agent 4470 puts ♧7 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♡8 from the played deck.
# StupidVictor-20 2.5 puts ♡8 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 12:
# [DEBUG] table card values:  [0, 7, 10, 12]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 4470 draws ♧8 from the played deck.
# RL Agent 4470 puts ♧8 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♧7 from the played deck.
# StupidVictor-20 2.5 puts ♧7 on the table at 2. row, 1. place
# ♤9 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 13:
# [DEBUG] table card values:  [0, 8, 10, 12]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: True
# RL Agent 4470 draws from the drawing deck.
# RL Agent 4470 puts ♡7 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♧8 from the played deck.
# StupidVictor-20 2.5 puts ♧8 on the table at 0. row, 3. place
# ♡10 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 14:
# [DEBUG] table card values:  [0, 7, 10, 12]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 9 total: 18 res: False
# RL Agent 4470 draws ♡10 from the played deck.
# RL Agent 4470 puts ♡10 on the table at 2. row, 2. place
# ♡7 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♡7 from the played deck.
# ♡7 is placed in the played deck by StupidVictor-20 2.5.
# ------------
# Turn 15:
# [DEBUG] table card values:  [0, 10, 10, 12]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 4470 draws ♡7 from the played deck.
# RL Agent 4470 puts ♡7 on the table at 2. row, 2. place
# ♡10 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♧2 on the table at 0. row, 2. place
# ♤11 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 16:
# [DEBUG] table card values:  [0, 7, 10, 12]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: True
# RL Agent 4470 draws from the drawing deck.
# RL Agent 4470 puts ♡5 on the table at 2. row, 2. place
# ♡7 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♡7 from the played deck.
# StupidVictor-20 2.5 puts ♡7 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 17:
# [DEBUG] table card values:  [0, 5, 10, 12]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 4470 draws ♡8 from the played deck.
# RL Agent 4470 puts ♡8 on the table at 2. row, 2. place
# ♡5 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♢6 on the table at 0. row, 1. place
# ♤12 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 18:
# [DEBUG] table card values:  [0, 8, 10, 12]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 4470 draws from the drawing deck.
# RL Agent 4470 puts ♧5 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♡1 on the table at 2. row, 1. place
# ♧7 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 19:
# [DEBUG] table card values:  [0, 5, 10, 12]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 4470 draws ♧7 from the played deck.
# RL Agent 4470 puts ♧7 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♧5 from the played deck.
# StupidVictor-20 2.5 puts ♧5 on the table at 0. row, 3. place
# ♧8 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 20:
# [DEBUG] table card values:  [0, 7, 10, 12]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 4470 draws ♧8 from the played deck.
# RL Agent 4470 puts ♧8 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws from the drawing deck.
# StupidVictor-20 2.5 puts ♧0 on the table at 0. row, 2. place
# ♧2 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 21:
# [DEBUG] table card values:  [0, 8, 10, 12]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 4470 draws ♧2 from the played deck.
# RL Agent 4470 puts ♧2 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♧8 from the played deck.
# StupidVictor-20 2.5 puts ♧8 on the table at 0. row, 1. place
# ♢6 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 22:
# [DEBUG] table card values:  [0, 2, 10, 12]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 4470 draws ♢6 from the played deck.
# RL Agent 4470 puts ♢6 on the table at 2. row, 2. place
# ♧2 is placed on the played deck from the table by RL Agent 4470
# StupidVictor-20 2.5 draws ♧2 from the played deck.
# StupidVictor-20 2.5 puts ♧2 on the table at 1. row, 3. place
# ♤4 is placed on the played deck from the table by StupidVictor-20 2.5
# ------------
# Turn 23:
# [DEBUG] table card values:  [0, 6, 10, 12]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: True
# RL Agent 4470 draws from the drawing deck.
# RL Agent 4470 puts ♤1 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 4470
# ...
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 6601 draws ♧5 from the played deck.
# RL Agent 6601 puts ♧5 on the table at 2. row, 2. place
# ♢9 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 5:
# StupidM$-DOS 3.9 draws ♢9 from the played deck.
# ♢9 is placed in the played deck by StupidM$-DOS 3.9.
# [DEBUG] table card values:  [12, 5, 0, 10]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6601 draws ♢9 from the played deck.
# RL Agent 6601 puts ♢9 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 6:
# StupidM$-DOS 3.9 draws from the drawing deck.
# StupidM$-DOS 3.9 puts ♡2 on the table at 1. row, 2. place
# ♢7 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 9, 0, 10]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 6601 draws ♢7 from the played deck.
# RL Agent 6601 puts ♢7 on the table at 2. row, 2. place
# ♢9 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 7:
# StupidM$-DOS 3.9 draws from the drawing deck.
# StupidM$-DOS 3.9 puts ♢6 on the table at 0. row, 1. place
# ♡12 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 7, 0, 10]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 6601 draws from the drawing deck.
# RL Agent 6601 puts ♤5 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 8:
# StupidM$-DOS 3.9 draws ♢7 from the played deck.
# StupidM$-DOS 3.9 puts ♢7 on the table at 1. row, 1. place
# ♧6 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 5, 0, 10]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 6601 draws ♧6 from the played deck.
# RL Agent 6601 puts ♧6 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 9:
# StupidM$-DOS 3.9 draws ♤5 from the played deck.
# StupidM$-DOS 3.9 puts ♤5 on the table at 0. row, 1. place
# ♢6 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 6, 0, 10]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 6601 draws ♢6 from the played deck.
# RL Agent 6601 puts ♢6 on the table at 2. row, 2. place
# ♧6 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 10:
# StupidM$-DOS 3.9 draws ♧6 from the played deck.
# StupidM$-DOS 3.9 puts ♧6 on the table at 0. row, 1. place
# ♤5 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 6, 0, 10]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 6601 draws ♤5 from the played deck.
# RL Agent 6601 puts ♤5 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 11:
# StupidM$-DOS 3.9 draws from the drawing deck.
# StupidM$-DOS 3.9 puts ♡10 on the table at 0. row, 3. place
# ♢3 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 5, 0, 10]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 6601 draws ♢3 from the played deck.
# RL Agent 6601 puts ♢3 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 12:
# StupidM$-DOS 3.9 draws from the drawing deck.
# StupidM$-DOS 3.9 puts ♡6 on the table at 0. row, 2. place
# ♤2 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 3, 0, 10]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 6601 draws ♤2 from the played deck.
# RL Agent 6601 puts ♤2 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 6601
# ------------
# Turn 13:
# StupidM$-DOS 3.9 draws ♢3 from the played deck.
# StupidM$-DOS 3.9 puts ♢3 on the table at 2. row, 2. place
# ♧9 is placed on the played deck from the table by StupidM$-DOS 3.9
# [DEBUG] table card values:  [12, 2, 0, 10]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6601 draws ♧9 from the played deck.
# RL Agent 6601 puts ♧9 on the table at 2. row, 2. place
# ♤2 is placed on the played deck from the table by RL Agent 6601
# Game over in 13 rounds!
# Scores:
# StupidM$-DOS 3.9: 56
# RL Agent 6601: 61
# RL Agent 6620 turns the initial cards visible.
# StupidKommodore K64 1.5 turns the initial cards visible.
# Players shuffled, player RL Agent 6620 starts...
# Complete init
# ------------
# Turn 1:
# [DEBUG] table card values:  [10, 5, 9]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 1 total: 10 res: True
# RL Agent 6620 draws from the drawing deck.
# RL Agent 6620 puts ♢8 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♡3 on the table at 2. row, 1. place
# ♤7 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 2:
# [DEBUG] table card values:  [10, 8, 9]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6620 draws ♤7 from the played deck.
# RL Agent 6620 puts ♤7 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♢8 from the played deck.
# StupidKommodore K64 1.5 puts ♢8 on the table at 2. row, 3. place
# ♤3 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 3:
# [DEBUG] table card values:  [10, 7, 9]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 6620 draws ♤3 from the played deck.
# RL Agent 6620 puts ♤3 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♡9 on the table at 0. row, 1. place
# ♡10 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 4:
# [DEBUG] table card values:  [10, 3, 9]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 1 total: 10 res: True
# RL Agent 6620 draws from the drawing deck.
# RL Agent 6620 puts ♡4 on the table at 2. row, 2. place
# ♤3 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♧6 on the table at 0. row, 2. place
# ♧7 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 5:
# [DEBUG] table card values:  [10, 4, 9]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6620 draws ♧7 from the played deck.
# RL Agent 6620 puts ♧7 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♡4 from the played deck.
# StupidKommodore K64 1.5 puts ♡4 on the table at 1. row, 1. place
# ♢3 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 6:
# [DEBUG] table card values:  [10, 7, 9]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 6620 draws ♢3 from the played deck.
# RL Agent 6620 puts ♢3 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♧7 from the played deck.
# StupidKommodore K64 1.5 puts ♧7 on the table at 0. row, 1. place
# ♡9 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 7:
# [DEBUG] table card values:  [10, 3, 9]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 6620 draws ♡9 from the played deck.
# RL Agent 6620 puts ♡9 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♧4 on the table at 2. row, 3. place
# ♢8 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 8:
# [DEBUG] table card values:  [10, 9, 9]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 6620 draws ♢8 from the played deck.
# RL Agent 6620 puts ♢8 on the table at 2. row, 2. place
# ♡9 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♡9 from the played deck.
# StupidKommodore K64 1.5 puts ♡9 on the table at 0. row, 3. place
# ♢6 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 9:
# [DEBUG] table card values:  [10, 8, 9]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 6620 draws ♢6 from the played deck.
# RL Agent 6620 puts ♢6 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♢8 from the played deck.
# StupidKommodore K64 1.5 puts ♢8 on the table at 1. row, 3. place
# ♤9 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 10:
# [DEBUG] table card values:  [10, 6, 9]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 6620 draws ♤9 from the played deck.
# RL Agent 6620 puts ♤9 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♧8 on the table at 1. row, 2. place
# ♡7 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 11:
# [DEBUG] table card values:  [10, 9, 9]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 6620 draws ♡7 from the played deck.
# RL Agent 6620 puts ♡7 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♤9 from the played deck.
# StupidKommodore K64 1.5 puts ♤9 on the table at 2. row, 1. place
# ♡3 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 12:
# [DEBUG] table card values:  [10, 7, 9]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 6620 draws ♡3 from the played deck.
# RL Agent 6620 puts ♡3 on the table at 2. row, 2. place
# ♡7 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♤10 on the table at 0. row, 2. place
# ♧6 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 13:
# [DEBUG] table card values:  [10, 3, 9]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 6620 draws ♧6 from the played deck.
# RL Agent 6620 puts ♧6 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♧9 on the table at 0. row, 2. place
# ♤10 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 14:
# [DEBUG] table card values:  [10, 6, 9]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 1 total: 10 res: True
# RL Agent 6620 draws from the drawing deck.
# RL Agent 6620 puts ♧12 on the table at 2. row, 2. place
# ♧6 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♧6 from the played deck.
# StupidKommodore K64 1.5 puts ♧6 on the table at 0. row, 1. place
# ♧7 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 15:
# [DEBUG] table card values:  [10, 12, 9]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 6620 draws ♧7 from the played deck.
# RL Agent 6620 puts ♧7 on the table at 2. row, 2. place
# ♧12 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♤4 on the table at 2. row, 1. place
# ♤9 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 16:
# [DEBUG] table card values:  [10, 7, 9]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: True
# RL Agent 6620 draws from the drawing deck.
# RL Agent 6620 puts ♧3 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♢7 on the table at 2. row, 1. place
# ♤4 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 17:
# [DEBUG] table card values:  [10, 3, 9]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 6620 draws ♤4 from the played deck.
# RL Agent 6620 puts ♤4 on the table at 2. row, 2. place
# ♧3 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♧1 on the table at 1. row, 3. place
# ♢8 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 18:
# [DEBUG] table card values:  [10, 4, 9]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 6620 draws ♢8 from the played deck.
# RL Agent 6620 puts ♢8 on the table at 2. row, 2. place
# ♤4 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♤4 from the played deck.
# StupidKommodore K64 1.5 puts ♤4 on the table at 1. row, 2. place
# ♧8 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 19:
# [DEBUG] table card values:  [10, 8, 9]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 6620 draws ♧8 from the played deck.
# RL Agent 6620 puts ♧8 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♡2 on the table at 0. row, 2. place
# ♧9 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 20:
# [DEBUG] table card values:  [10, 8, 9]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 6620 draws ♧9 from the played deck.
# RL Agent 6620 puts ♧9 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws ♧8 from the played deck.
# StupidKommodore K64 1.5 puts ♧8 on the table at 1. row, 2. place
# ♤4 is placed on the played deck from the table by StupidKommodore K64 1.5
# ------------
# Turn 21:
# [DEBUG] table card values:  [10, 9, 9]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 6620 draws ♤4 from the played deck.
# RL Agent 6620 puts ♤4 on the table at 2. row, 2. place
# ♧9 is placed on the played deck from the table by RL Agent 6620
# StupidKommodore K64 1.5 draws from the drawing deck.
# StupidKommodore K64 1.5 puts ♢1 on the table at 2. row, 2. place
# ♡11 is placed on the played deck from the table by StupidKommodore K64 1.5
# Game over in 21 rounds!
# Scores:
# RL Agent 6620: 55
# StupidKommodore K64 1.5: 42
# Turns quartiles:
# 0.25    16.0
# 0.50    21.0
# 0.75    26.0
# 1.00    50.0
# Name: turns, dtype: object
# Stupid player winning percentage: 60.0

# %%
results
# Out:
#                      winner turns Stupid player winner
# 0              RL Agent 637    11                False
# 1             RL Agent 6515    26                False
# 2              RL Agent 356    14                False
# 3             RL Agent 3182    19                False
# 4       StupidVictor-20 2.5    27                 True
# ..                      ...   ...                  ...
# 95            RL Agent 7450    23                False
# 96    StupidUNIWAC 1101 3.6    26                 True
# 97             RL Agent 505    26                False
# 98         StupidM$-DOS 3.9    13                 True
# 99  StupidKommodore K64 1.5    21                 True
#
# [100 rows x 3 columns]
