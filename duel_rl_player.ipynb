# %% [markdown]
# ## Test RL agent against different opponents

# %%
from src.game import Game
import pandas as pd

# %% [markdown]
# Different player types:
# "Stupid...", "RL Agent...", "Comput...", "Advanc...", "Human..."

# %%
BENCHMARK_PLAYER_DESC = "Stupid player"

# %% [markdown]
# Other constants

# %%
ITERATIONS = 100

# %% [markdown]
# Run test rounds

# %%
results = pd.DataFrame(columns=['winner', 'turns', BENCHMARK_PLAYER_DESC + " winner"])
for i in range(ITERATIONS):

    # Remember to set correct player type here, too
    game = Game(2, 
                human_player=False, 
                silent_mode=False, 
                stupid_player=True,
                advanced_player=False,
                rl_player=True)
    turns, score_dict, winner = game.play_game()
    benchmark_row = winner.startswith(BENCHMARK_PLAYER_DESC[:6])
    new_row = pd.DataFrame(
        {
            'winner': [winner], 
            'turns': [turns], 
            BENCHMARK_PLAYER_DESC + " winner": [benchmark_row]
        }
    )
    results = pd.concat([results, new_row], ignore_index=True)

print("Turns quartiles:")
quartiles = results['turns'].quantile([0.25, 0.5, 0.75, 1.0])
print(quartiles)
print(f"{BENCHMARK_PLAYER_DESC} winning percentage: {results[BENCHMARK_PLAYER_DESC + " winner"].mean() * 100}")
# Out:
# RL Agent 2939 turns the initial cards visible.
# StupidMc Birdbucket 1.8 turns the initial cards visible.
# Players shuffled, player RL Agent 2939 starts...
# Complete init
# ------------
# Turn 1:
# [DEBUG] table card values:  [11, 8, 2]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 225 total: 226 res: False
# RL Agent 2939 draws ♧1 from the played deck.
# RL Agent 2939 puts ♧1 on the table at 2. row, 1. place
# ♢8 is placed on the played deck from the table by RL Agent 2939
# StupidMc Birdbucket 1.8 draws ♢8 from the played deck.
# StupidMc Birdbucket 1.8 puts ♢8 on the table at 2. row, 1. place
# ♢5 is placed on the played deck from the table by StupidMc Birdbucket 1.8
# ------------
# Turn 2:
# [DEBUG] table card values:  [11, 1, 2]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 2939 draws ♢5 from the played deck.
# RL Agent 2939 puts ♢5 on the table at 2. row, 1. place
# ...

# %%
results
# Out:
#                      winner turns Stupid player winner
# 0   StupidMc Birdbucket 1.8    19                 True
# 1         StupidIPM 701 2.6    15                 True
# 2             RL Agent 4516    20                False
# 3       StupidVictor-20 2.8    40                 True
# 4             RL Agent 9731    16                False
# ..                      ...   ...                  ...
# 95         StupidM$-DOS 3.3    19                 True
# 96         StupidM$-DOS 3.8    28                 True
# 97      StupidVictor-20 3.5    10                 True
# 98      StupidVictor-20 1.1    18                 True
# 99    StupidUNIWAC 1101 2.8    19                 True
#
# [100 rows x 3 columns]
