# %% [markdown]
# ## Test RL agent against different opponents

# %%
from src.game import Game
import pandas as pd

# %% [markdown]
# Different player types:
# "Stupid...", "RL Agent...", "Comput...", "Advanc...", "Human..."

# %%
BENCHMARK_PLAYER_DESC = "Stupid player"

# %% [markdown]
# Other constants

# %%
ITERATIONS = 100

# %% [markdown]
# Run test rounds

# %%
results = pd.DataFrame(columns=['winner', 'turns', BENCHMARK_PLAYER_DESC + " winner"])
for i in range(ITERATIONS):

    # Remember to set correct player type here, too
    game = Game(2, 
                human_player=False, 
                silent_mode=False, 
                stupid_player=True,
                advanced_player=False,
                rl_player=True)
    turns, score_dict, winner = game.play_game()
    benchmark_row = winner.startswith(BENCHMARK_PLAYER_DESC[:6])
    new_row = pd.DataFrame(
        {
            'winner': [winner], 
            'turns': [turns], 
            BENCHMARK_PLAYER_DESC + " winner": [benchmark_row]
        }
    )
    results = pd.concat([results, new_row], ignore_index=True)

print("Turns quartiles:")
quartiles = results['turns'].quantile([0.25, 0.5, 0.75, 1.0])
print(quartiles)
print(f"{BENCHMARK_PLAYER_DESC} winning percentage: {results[BENCHMARK_PLAYER_DESC + " winner"].mean() * 100}")
# Out:
# RL Agent 906 turns the initial cards visible.
# StupidIPM 701 3.6 turns the initial cards visible.
# Players shuffled, player RL Agent 906 starts...
# Complete init
# ------------
# Turn 1:
# [DEBUG] table card values:  [2, 12, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♡6 from the played deck.
# RL Agent 906 puts ♡6 on the table at 2. row, 2. place
# ♢9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# ♤12 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 2:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♧1 on the table at 2. row, 2. place
# ♡6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡6 from the played deck.
# StupidIPM 701 3.6 puts ♡6 on the table at 0. row, 1. place
# ♤1 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 3:
# [DEBUG] table card values:  [2, 12, 1, 5]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 256 total: 257 res: False
# RL Agent 906 draws ♤1 from the played deck.
# RL Agent 906 puts ♤1 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤3 on the table at 2. row, 1. place
# ♧5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 4:
# [DEBUG] table card values:  [2, 12, 1, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♧5 from the played deck.
# RL Agent 906 puts ♧5 on the table at 2. row, 2. place
# ♤1 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢6 on the table at 2. row, 1. place
# ♤3 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 5:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 906 draws ♤3 from the played deck.
# RL Agent 906 puts ♤3 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧0 on the table at 1. row, 3. place
# ♤7 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 6:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 906 draws ♤7 from the played deck.
# RL Agent 906 puts ♤7 on the table at 2. row, 2. place
# ♤3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡9 on the table at 1. row, 3. place
# ♧0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 7:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♧0 from the played deck.
# RL Agent 906 puts ♧0 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤7 from the played deck.
# StupidIPM 701 3.6 puts ♤7 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 8:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 256 total: 257 res: False
# RL Agent 906 draws ♢1 from the played deck.
# RL Agent 906 puts ♢1 on the table at 2. row, 2. place
# ♧0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡8 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 9:
# [DEBUG] table card values:  [2, 12, 1, 5]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 906 draws ♤7 from the played deck.
# RL Agent 906 puts ♤7 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢2 on the table at 0. row, 2. place
# ♤11 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 10:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♢4 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤7 from the played deck.
# StupidIPM 701 3.6 puts ♤7 on the table at 1. row, 3. place
# ♡9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 11:
# [DEBUG] table card values:  [2, 12, 4, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♡9 from the played deck.
# RL Agent 906 puts ♡9 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢4 from the played deck.
# ♢4 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 12:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 906 draws ♢4 from the played deck.
# RL Agent 906 puts ♢4 on the table at 2. row, 2. place
# ♡9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧9 on the table at 1. row, 1. place
# ♡3 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 13:
# [DEBUG] table card values:  [2, 12, 4, 5]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 906 draws ♡3 from the played deck.
# RL Agent 906 puts ♡3 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢4 from the played deck.
# StupidIPM 701 3.6 puts ♢4 on the table at 0. row, 3. place
# ♡0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 14:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♡0 from the played deck.
# RL Agent 906 puts ♡0 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡3 from the played deck.
# StupidIPM 701 3.6 puts ♡3 on the table at 0. row, 2. place
# ♢2 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 15:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 906 draws ♢2 from the played deck.
# RL Agent 906 puts ♢2 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡0 from the played deck.
# StupidIPM 701 3.6 puts ♡0 on the table at 1. row, 2. place
# ♧4 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 16:
# [DEBUG] table card values:  [2, 12, 2, 5]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 906 draws ♧4 from the played deck.
# RL Agent 906 puts ♧4 on the table at 2. row, 2. place
# ♢2 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# ♢0 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 17:
# [DEBUG] table card values:  [2, 12, 4, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♢0 from the played deck.
# RL Agent 906 puts ♢0 on the table at 2. row, 2. place
# ♧4 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡11 on the table at 0. row, 3. place
# ♢4 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 18:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 906 draws ♢4 from the played deck.
# RL Agent 906 puts ♢4 on the table at 2. row, 2. place
# ♢0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# ♢12 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 19:
# [DEBUG] table card values:  [2, 12, 4, 5]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♢11 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤5 on the table at 1. row, 3. place
# ♤7 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 20:
# [DEBUG] table card values:  [2, 12, 11, 5]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 906 draws ♤7 from the played deck.
# RL Agent 906 puts ♤7 on the table at 2. row, 2. place
# ♢11 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢5 on the table at 1. row, 3. place
# ♤5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 21:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♤5 from the played deck.
# RL Agent 906 puts ♤5 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤7 from the played deck.
# StupidIPM 701 3.6 puts ♤7 on the table at 0. row, 1. place
# ♡6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 22:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♡6 from the played deck.
# RL Agent 906 puts ♡6 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤5 from the played deck.
# StupidIPM 701 3.6 puts ♤5 on the table at 2. row, 1. place
# ♢6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 23:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♢6 from the played deck.
# RL Agent 906 puts ♢6 on the table at 2. row, 2. place
# ♡6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤6 on the table at 0. row, 3. place
# ♡11 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 24:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♧7 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢6 from the played deck.
# StupidIPM 701 3.6 puts ♢6 on the table at 1. row, 3. place
# ♢5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 25:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♢5 from the played deck.
# RL Agent 906 puts ♢5 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♧7 from the played deck.
# StupidIPM 701 3.6 puts ♧7 on the table at 1. row, 2. place
# ♡0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 26:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♡0 from the played deck.
# RL Agent 906 puts ♡0 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧10 on the table at 0. row, 2. place
# ♡3 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 27:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 906 draws ♡3 from the played deck.
# RL Agent 906 puts ♡3 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡0 from the played deck.
# ♡0 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 28:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♡0 from the played deck.
# RL Agent 906 puts ♡0 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡12 on the table at 1. row, 1. place
# ♧9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 29:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♧9 from the played deck.
# RL Agent 906 puts ♧9 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤9 on the table at 0. row, 3. place
# ♤6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 30:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♤6 from the played deck.
# RL Agent 906 puts ♤6 on the table at 2. row, 2. place
# ♧9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢10 on the table at 0. row, 1. place
# ♤7 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 31:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 906 draws ♤7 from the played deck.
# RL Agent 906 puts ♤7 on the table at 2. row, 2. place
# ♤6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# ♧3 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 32:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 906 draws ♧3 from the played deck.
# RL Agent 906 puts ♧3 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢8 on the table at 0. row, 2. place
# ♧10 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 33:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 9 total: 18 res: False
# RL Agent 906 draws ♧10 from the played deck.
# RL Agent 906 puts ♧10 on the table at 2. row, 2. place
# ♧3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢3 on the table at 1. row, 3. place
# ♢6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 34:
# [DEBUG] table card values:  [2, 12, 10, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♢6 from the played deck.
# RL Agent 906 puts ♢6 on the table at 2. row, 2. place
# ♧10 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤0 on the table at 0. row, 2. place
# ♢8 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 35:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 906 draws ♢8 from the played deck.
# RL Agent 906 puts ♢8 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢6 from the played deck.
# StupidIPM 701 3.6 puts ♢6 on the table at 0. row, 3. place
# ♤9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 36:
# [DEBUG] table card values:  [2, 12, 8, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♤9 from the played deck.
# RL Agent 906 puts ♤9 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧11 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 37:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 906 draws ♡8 from the played deck.
# RL Agent 906 puts ♡8 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤9 from the played deck.
# StupidIPM 701 3.6 puts ♤9 on the table at 0. row, 1. place
# ♢10 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 38:
# [DEBUG] table card values:  [2, 12, 8, 5]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 9 total: 18 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♡2 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡8 from the played deck.
# ♡8 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 39:
# [DEBUG] table card values:  [2, 12, 2, 5]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 906 draws ♡8 from the played deck.
# RL Agent 906 puts ♡8 on the table at 2. row, 2. place
# ♡2 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡2 from the played deck.
# ♡2 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 40:
# [DEBUG] table card values:  [2, 12, 8, 5]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 906 draws ♡2 from the played deck.
# RL Agent 906 puts ♡2 on the table at 2. row, 2. place
# ♡8 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤8 on the table at 1. row, 3. place
# ♢3 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 41:
# [DEBUG] table card values:  [2, 12, 2, 5]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 906 draws ♢3 from the played deck.
# RL Agent 906 puts ♢3 on the table at 2. row, 2. place
# ♡2 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡4 on the table at 2. row, 1. place
# ♤5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 42:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♤5 from the played deck.
# RL Agent 906 puts ♤5 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤2 on the table at 2. row, 1. place
# ♡4 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 43:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 906 draws ♡4 from the played deck.
# RL Agent 906 puts ♡4 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤5 from the played deck.
# StupidIPM 701 3.6 puts ♤5 on the table at 0. row, 1. place
# ♤9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 44:
# [DEBUG] table card values:  [2, 12, 4, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♤9 from the played deck.
# RL Agent 906 puts ♤9 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤4 on the table at 0. row, 3. place
# ♢6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 45:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♢6 from the played deck.
# RL Agent 906 puts ♢6 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤9 from the played deck.
# StupidIPM 701 3.6 puts ♤9 on the table at 2. row, 2. place
# ♧11 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 46:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♧8 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧0 on the table at 0. row, 1. place
# ♤5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 47:
# [DEBUG] table card values:  [2, 12, 8, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♤5 from the played deck.
# RL Agent 906 puts ♤5 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢6 on the table at 2. row, 1. place
# ♤2 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 48:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 906 draws ♤2 from the played deck.
# RL Agent 906 puts ♤2 on the table at 2. row, 2. place
# ♤5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡0 on the table at 0. row, 1. place
# ♧0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 49:
# [DEBUG] table card values:  [2, 12, 2, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♧0 from the played deck.
# RL Agent 906 puts ♧0 on the table at 2. row, 2. place
# ♤2 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡2 on the table at 1. row, 2. place
# ♧7 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 50:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 906 draws ♧7 from the played deck.
# RL Agent 906 puts ♧7 on the table at 2. row, 2. place
# ♧0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# ♢10 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 51:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 9 total: 18 res: False
# RL Agent 906 draws ♢10 from the played deck.
# RL Agent 906 puts ♢10 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# ♡9 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 52:
# [DEBUG] table card values:  [2, 12, 10, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♡9 from the played deck.
# RL Agent 906 puts ♡9 on the table at 2. row, 2. place
# ♢10 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢10 from the played deck.
# StupidIPM 701 3.6 puts ♢10 on the table at 1. row, 1. place
# ♡12 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 53:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♢11 on the table at 2. row, 2. place
# ♡9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡9 from the played deck.
# StupidIPM 701 3.6 puts ♡9 on the table at 1. row, 2. place
# ♡2 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 54:
# [DEBUG] table card values:  [2, 12, 11, 5]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 169 total: 170 res: False
# RL Agent 906 draws ♡2 from the played deck.
# RL Agent 906 puts ♡2 on the table at 2. row, 2. place
# ♢11 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢11 from the played deck.
# ♢11 is placed in the played deck by StupidIPM 701 3.6.
# ------------
# Turn 55:
# [DEBUG] table card values:  [2, 12, 2, 5]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: False
# RL Agent 906 draws ♢11 from the played deck.
# RL Agent 906 puts ♢11 on the table at 2. row, 2. place
# ♡2 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢1 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 56:
# [DEBUG] table card values:  [2, 12, 11, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♤9 from the played deck.
# RL Agent 906 puts ♤9 on the table at 2. row, 2. place
# ♢11 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢11 from the played deck.
# StupidIPM 701 3.6 puts ♢11 on the table at 0. row, 1. place
# ♡0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 57:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♡0 from the played deck.
# RL Agent 906 puts ♡0 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤9 from the played deck.
# StupidIPM 701 3.6 puts ♤9 on the table at 1. row, 3. place
# ♤8 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 58:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 906 draws ♤8 from the played deck.
# RL Agent 906 puts ♤8 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡0 from the played deck.
# StupidIPM 701 3.6 puts ♡0 on the table at 2. row, 1. place
# ♢6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 59:
# [DEBUG] table card values:  [2, 12, 8, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♢6 from the played deck.
# RL Agent 906 puts ♢6 on the table at 2. row, 2. place
# ♤8 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤3 on the table at 1. row, 3. place
# ♤9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 60:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♤9 from the played deck.
# RL Agent 906 puts ♤9 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢5 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 61:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 256 total: 257 res: False
# RL Agent 906 draws ♢1 from the played deck.
# RL Agent 906 puts ♢1 on the table at 2. row, 2. place
# ♤9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤12 on the table at 1. row, 1. place
# ♢10 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 62:
# [DEBUG] table card values:  [2, 12, 1, 5]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 9 total: 18 res: False
# RL Agent 906 draws ♢10 from the played deck.
# RL Agent 906 puts ♢10 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧1 on the table at 0. row, 2. place
# ♤0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 63:
# [DEBUG] table card values:  [2, 12, 10, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♤0 from the played deck.
# RL Agent 906 puts ♤0 on the table at 2. row, 2. place
# ♢10 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤7 on the table at 1. row, 2. place
# ♡9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 64:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♡9 from the played deck.
# RL Agent 906 puts ♡9 on the table at 2. row, 2. place
# ♤0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♤0 from the played deck.
# StupidIPM 701 3.6 puts ♤0 on the table at 1. row, 3. place
# ♤3 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 65:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 100 total: 101 res: False
# RL Agent 906 draws ♤3 from the played deck.
# RL Agent 906 puts ♤3 on the table at 2. row, 2. place
# ♡9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♡9 from the played deck.
# StupidIPM 701 3.6 puts ♡9 on the table at 1. row, 2. place
# ♤7 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 66:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 906 draws ♤7 from the played deck.
# RL Agent 906 puts ♤7 on the table at 2. row, 2. place
# ♤3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢12 on the table at 2. row, 1. place
# ♡0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 67:
# [DEBUG] table card values:  [2, 12, 7, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♡0 from the played deck.
# RL Agent 906 puts ♡0 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♤6 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 68:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♢5 from the played deck.
# RL Agent 906 puts ♢5 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♢0 on the table at 0. row, 1. place
# ♢11 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 69:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 4 total: 29 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♢9 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢5 from the played deck.
# StupidIPM 701 3.6 puts ♢5 on the table at 1. row, 1. place
# ♤12 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 70:
# [DEBUG] table card values:  [2, 12, 9, 5]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 49 played_inc: 1 total: 50 res: True
# RL Agent 906 draws from the drawing deck.
# RL Agent 906 puts ♢3 on the table at 2. row, 2. place
# ♢9 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢9 from the played deck.
# StupidIPM 701 3.6 puts ♢9 on the table at 0. row, 3. place
# ♤4 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 71:
# [DEBUG] table card values:  [2, 12, 3, 5]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 906 draws ♤4 from the played deck.
# RL Agent 906 puts ♤4 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢3 from the played deck.
# StupidIPM 701 3.6 puts ♢3 on the table at 0. row, 1. place
# ♢0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 72:
# [DEBUG] table card values:  [2, 12, 4, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♢0 from the played deck.
# RL Agent 906 puts ♢0 on the table at 2. row, 2. place
# ♤4 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡11 on the table at 1. row, 1. place
# ♢5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 73:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♢5 from the played deck.
# RL Agent 906 puts ♢5 on the table at 2. row, 2. place
# ♢0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♧5 on the table at 0. row, 2. place
# ♧1 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 74:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 256 total: 257 res: False
# RL Agent 906 draws ♧1 from the played deck.
# RL Agent 906 puts ♧1 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♢5 from the played deck.
# StupidIPM 701 3.6 puts ♢5 on the table at 0. row, 2. place
# ♧5 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 75:
# [DEBUG] table card values:  [2, 12, 1, 5]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 906 draws ♧5 from the played deck.
# RL Agent 906 puts ♧5 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♧1 from the played deck.
# StupidIPM 701 3.6 puts ♧1 on the table at 2. row, 2. place
# ♤6 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 76:
# [DEBUG] table card values:  [2, 12, 5, 5]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 906 draws ♤6 from the played deck.
# RL Agent 906 puts ♤6 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws ♧5 from the played deck.
# StupidIPM 701 3.6 puts ♧5 on the table at 1. row, 3. place
# ♤0 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 77:
# [DEBUG] table card values:  [2, 12, 6, 5]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 361 total: 362 res: False
# RL Agent 906 draws ♤0 from the played deck.
# RL Agent 906 puts ♤0 on the table at 2. row, 2. place
# ♤6 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡4 on the table at 0. row, 3. place
# ♢9 is placed on the played deck from the table by StupidIPM 701 3.6
# ------------
# Turn 78:
# [DEBUG] table card values:  [2, 12, 0, 5]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 906 draws ♢9 from the played deck.
# RL Agent 906 puts ♢9 on the table at 2. row, 2. place
# ♤0 is placed on the played deck from the table by RL Agent 906
# StupidIPM 701 3.6 draws from the drawing deck.
# StupidIPM 701 3.6 puts ♡3 on the table at 2. row, 3. place
# ♧6 is placed on the played deck from the table by StupidIPM 701 3.6
# Game over in 78 rounds!
# Scores:
# RL Agent 906: 63
# StupidIPM 701 3.6: 53
# RL Agent 2396 turns the initial cards visible.
# StupidMc Birdbucket 2.9 turns the initial cards visible.
# Players shuffled, player StupidMc Birdbucket 2.9 starts...
# Complete init
# ------------
# Turn 1:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♡0 on the table at 0. row, 2. place
# ♡5 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 3, 2]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: False
# RL Agent 2396 draws ♡5 from the played deck.
# RL Agent 2396 puts ♡5 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 2:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♡2 on the table at 2. row, 3. place
# ♤4 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 5, 2]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 4 total: 5 res: False
# RL Agent 2396 draws ♤4 from the played deck.
# RL Agent 2396 puts ♤4 on the table at 2. row, 2. place
# ♡5 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 3:
# StupidMc Birdbucket 2.9 draws ♡5 from the played deck.
# StupidMc Birdbucket 2.9 puts ♡5 on the table at 2. row, 1. place
# ♡11 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 4, 2]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 144 played_inc: 1 total: 145 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♢11 on the table at 2. row, 2. place
# ♤4 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 4:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♡7 on the table at 0. row, 2. place
# ♡0 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 11, 2]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 324 total: 325 res: False
# RL Agent 2396 draws ♡0 from the played deck.
# RL Agent 2396 puts ♡0 on the table at 2. row, 2. place
# ♢11 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 5:
# StupidMc Birdbucket 2.9 draws ♢11 from the played deck.
# ♢11 is placed in the played deck by StupidMc Birdbucket 2.9.
# [DEBUG] table card values:  [4, 0, 2]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 144 played_inc: 1 total: 145 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♡12 on the table at 2. row, 2. place
# ♡0 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 6:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# ♧8 is placed in the played deck by StupidMc Birdbucket 2.9.
# [DEBUG] table card values:  [4, 12, 2]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 2396 draws ♧8 from the played deck.
# RL Agent 2396 puts ♧8 on the table at 2. row, 2. place
# ♡12 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 7:
# StupidMc Birdbucket 2.9 draws ♡12 from the played deck.
# StupidMc Birdbucket 2.9 puts ♡12 on the table at 1. row, 2. place
# ♡6 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 8, 2]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 9 total: 10 res: False
# RL Agent 2396 draws ♡6 from the played deck.
# RL Agent 2396 puts ♡6 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 8:
# StupidMc Birdbucket 2.9 draws ♧8 from the played deck.
# StupidMc Birdbucket 2.9 puts ♧8 on the table at 1. row, 2. place
# ♡12 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 6, 2]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 169 played_inc: 1 total: 170 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♧2 on the table at 2. row, 2. place
# ♡6 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 9:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# ♧6 is placed in the played deck by StupidMc Birdbucket 2.9.
# [DEBUG] table card values:  [4, 2, 2]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 1 total: 10 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♢3 on the table at 2. row, 2. place
# ♧2 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 10:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# ♧5 is placed in the played deck by StupidMc Birdbucket 2.9.
# [DEBUG] table card values:  [4, 3, 2]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♤8 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 11:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♤3 on the table at 2. row, 3. place
# ♡2 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 8, 2]
# [DEBUG] played card value:  2
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 2396 draws ♡2 from the played deck.
# RL Agent 2396 puts ♡2 on the table at 2. row, 2. place
# ♤8 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 12:
# StupidMc Birdbucket 2.9 draws ♤8 from the played deck.
# StupidMc Birdbucket 2.9 puts ♤8 on the table at 1. row, 3. place
# ♢8 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 2, 2]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 1 total: 26 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♢6 on the table at 2. row, 2. place
# ♡2 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 13:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♤10 on the table at 1. row, 2. place
# ♧8 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 6, 2]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 1 total: 10 res: False
# RL Agent 2396 draws ♧8 from the played deck.
# RL Agent 2396 puts ♧8 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 14:
# StupidMc Birdbucket 2.9 draws ♢6 from the played deck.
# StupidMc Birdbucket 2.9 puts ♢6 on the table at 1. row, 1. place
# ♢12 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 8, 2]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 121 played_inc: 1 total: 122 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♢5 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 15:
# StupidMc Birdbucket 2.9 draws ♧8 from the played deck.
# StupidMc Birdbucket 2.9 puts ♧8 on the table at 2. row, 2. place
# ♤0 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 5, 2]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 144 total: 145 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♤6 on the table at 2. row, 2. place
# ♢5 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 16:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♧12 on the table at 0. row, 2. place
# ♡7 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 6, 2]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♢7 on the table at 2. row, 2. place
# ♤6 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 17:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♡9 on the table at 2. row, 2. place
# ♧8 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 7, 2]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 4 played_inc: 1 total: 5 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♤2 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 18:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♡1 on the table at 0. row, 2. place
# ♧12 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 2, 2]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 225 played_inc: 1 total: 226 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♡4 on the table at 2. row, 2. place
# ♤2 is placed on the played deck from the table by RL Agent 2396
# ------------
# Turn 19:
# StupidMc Birdbucket 2.9 draws from the drawing deck.
# StupidMc Birdbucket 2.9 puts ♢10 on the table at 2. row, 2. place
# ♡9 is placed on the played deck from the table by StupidMc Birdbucket 2.9
# [DEBUG] table card values:  [4, 4, 2]
# [DEBUG] played card value:  9
# [DEBUG] Did lottery: deck_inc: 36 played_inc: 1 total: 37 res: True
# RL Agent 2396 draws from the drawing deck.
# RL Agent 2396 puts ♡10 on the table at 2. row, 2. place
# ...
# RL Agent 7633 draws ♤4 from the played deck.
# RL Agent 7633 puts ♤4 on the table at 2. row, 2. place
# ♢1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 4:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♡3 on the table at 0. row, 1. place
# ♤10 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 4, 11]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 4 total: 13 res: True
# RL Agent 7633 draws from the drawing deck.
# RL Agent 7633 puts ♧5 on the table at 2. row, 2. place
# ♤4 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 5:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♢10 on the table at 1. row, 3. place
# ♢6 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 5, 11]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 7633 draws ♢6 from the played deck.
# RL Agent 7633 puts ♢6 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 6:
# StupidM$-DOS 3.6 draws ♧5 from the played deck.
# ♧5 is placed in the played deck by StupidM$-DOS 3.6.
# [DEBUG] table card values:  [0, 6, 11]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 7633 draws ♧5 from the played deck.
# RL Agent 7633 puts ♧5 on the table at 2. row, 2. place
# ♢6 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 7:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♤1 on the table at 2. row, 1. place
# ♤12 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 5, 11]
# [DEBUG] played card value:  12
# [DEBUG] Did lottery: deck_inc: 64 played_inc: 1 total: 65 res: True
# RL Agent 7633 draws from the drawing deck.
# RL Agent 7633 puts ♡1 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 8:
# StupidM$-DOS 3.6 draws ♧5 from the played deck.
# StupidM$-DOS 3.6 puts ♧5 on the table at 0. row, 3. place
# ♢4 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 1, 11]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 7633 draws ♢4 from the played deck.
# RL Agent 7633 puts ♢4 on the table at 2. row, 2. place
# ♡1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 9:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♢8 on the table at 2. row, 1. place
# ♤1 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 4, 11]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 225 total: 226 res: False
# RL Agent 7633 draws ♤1 from the played deck.
# RL Agent 7633 puts ♤1 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 10:
# StupidM$-DOS 3.6 draws ♢4 from the played deck.
# ♢4 is placed in the played deck by StupidM$-DOS 3.6.
# [DEBUG] table card values:  [0, 1, 11]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 7633 draws ♢4 from the played deck.
# RL Agent 7633 puts ♢4 on the table at 2. row, 2. place
# ♤1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 11:
# StupidM$-DOS 3.6 draws ♤1 from the played deck.
# StupidM$-DOS 3.6 puts ♤1 on the table at 0. row, 3. place
# ♧5 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 4, 11]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 7633 draws ♧5 from the played deck.
# RL Agent 7633 puts ♧5 on the table at 2. row, 2. place
# ♢4 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 12:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♡7 on the table at 1. row, 2. place
# ♢3 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 5, 11]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 7633 draws ♢3 from the played deck.
# RL Agent 7633 puts ♢3 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 13:
# StupidM$-DOS 3.6 draws ♧5 from the played deck.
# StupidM$-DOS 3.6 puts ♧5 on the table at 0. row, 3. place
# ♤1 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 3, 11]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 225 total: 226 res: False
# RL Agent 7633 draws ♤1 from the played deck.
# RL Agent 7633 puts ♤1 on the table at 2. row, 2. place
# ♢3 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 14:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♧0 on the table at 2. row, 1. place
# ♢8 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 1, 11]
# [DEBUG] played card value:  8
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 16 total: 17 res: False
# RL Agent 7633 draws ♢8 from the played deck.
# RL Agent 7633 puts ♢8 on the table at 2. row, 2. place
# ♤1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 15:
# StupidM$-DOS 3.6 draws ♤1 from the played deck.
# StupidM$-DOS 3.6 puts ♤1 on the table at 1. row, 1. place
# ♢7 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 8, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♢7 from the played deck.
# RL Agent 7633 puts ♢7 on the table at 2. row, 2. place
# ♢8 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 16:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♧1 on the table at 1. row, 1. place
# ♤1 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 225 total: 226 res: False
# RL Agent 7633 draws ♤1 from the played deck.
# RL Agent 7633 puts ♤1 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 17:
# StupidM$-DOS 3.6 draws ♢7 from the played deck.
# ♢7 is placed in the played deck by StupidM$-DOS 3.6.
# [DEBUG] table card values:  [0, 1, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♢7 from the played deck.
# RL Agent 7633 puts ♢7 on the table at 2. row, 2. place
# ♤1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 18:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♧6 on the table at 0. row, 3. place
# ♧5 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 7633 draws ♧5 from the played deck.
# RL Agent 7633 puts ♧5 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 19:
# StupidM$-DOS 3.6 draws ♢7 from the played deck.
# ♢7 is placed in the played deck by StupidM$-DOS 3.6.
# [DEBUG] table card values:  [0, 5, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♢7 from the played deck.
# RL Agent 7633 puts ♢7 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 20:
# StupidM$-DOS 3.6 draws ♧5 from the played deck.
# StupidM$-DOS 3.6 puts ♧5 on the table at 1. row, 3. place
# ♢10 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 4 total: 13 res: False
# RL Agent 7633 draws ♢10 from the played deck.
# RL Agent 7633 puts ♢10 on the table at 2. row, 2. place
# ♢7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 21:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♤7 on the table at 0. row, 2. place
# ♧7 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 10, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♧7 from the played deck.
# RL Agent 7633 puts ♧7 on the table at 2. row, 2. place
# ♢10 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 22:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♡11 on the table at 1. row, 1. place
# ♧1 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 225 total: 226 res: False
# RL Agent 7633 draws ♧1 from the played deck.
# RL Agent 7633 puts ♧1 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 23:
# StupidM$-DOS 3.6 draws ♧7 from the played deck.
# StupidM$-DOS 3.6 puts ♧7 on the table at 0. row, 2. place
# ♤7 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 1, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♤7 from the played deck.
# RL Agent 7633 puts ♤7 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 24:
# StupidM$-DOS 3.6 draws ♧1 from the played deck.
# StupidM$-DOS 3.6 puts ♧1 on the table at 0. row, 1. place
# ♡3 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  3
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 81 total: 82 res: False
# RL Agent 7633 draws ♡3 from the played deck.
# RL Agent 7633 puts ♡3 on the table at 2. row, 2. place
# ♤7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 25:
# StupidM$-DOS 3.6 draws ♤7 from the played deck.
# StupidM$-DOS 3.6 puts ♤7 on the table at 0. row, 2. place
# ♧7 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 3, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♧7 from the played deck.
# RL Agent 7633 puts ♧7 on the table at 2. row, 2. place
# ♡3 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 26:
# StupidM$-DOS 3.6 draws ♡3 from the played deck.
# StupidM$-DOS 3.6 puts ♡3 on the table at 2. row, 1. place
# ♧0 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  0
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 324 total: 325 res: False
# RL Agent 7633 draws ♧0 from the played deck.
# RL Agent 7633 puts ♧0 on the table at 2. row, 2. place
# ♧7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 27:
# StupidM$-DOS 3.6 draws ♧7 from the played deck.
# StupidM$-DOS 3.6 puts ♧7 on the table at 1. row, 3. place
# ♧5 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 0, 11]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 7633 draws ♧5 from the played deck.
# RL Agent 7633 puts ♧5 on the table at 2. row, 2. place
# ♧0 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 28:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♧3 on the table at 0. row, 3. place
# ♧6 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 5, 11]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 7633 draws ♧6 from the played deck.
# RL Agent 7633 puts ♧6 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 29:
# StupidM$-DOS 3.6 draws ♧5 from the played deck.
# StupidM$-DOS 3.6 puts ♧5 on the table at 0. row, 1. place
# ♧1 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 6, 11]
# [DEBUG] played card value:  1
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 225 total: 226 res: False
# RL Agent 7633 draws ♧1 from the played deck.
# RL Agent 7633 puts ♧1 on the table at 2. row, 2. place
# ♧6 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 30:
# StupidM$-DOS 3.6 draws ♧6 from the played deck.
# StupidM$-DOS 3.6 puts ♧6 on the table at 1. row, 1. place
# ♡11 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 1, 11]
# [DEBUG] played card value:  11
# [DEBUG] Did lottery: deck_inc: 25 played_inc: 1 total: 26 res: True
# RL Agent 7633 draws from the drawing deck.
# RL Agent 7633 puts ♤0 on the table at 2. row, 2. place
# ♧1 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 31:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♡8 on the table at 1. row, 2. place
# ♡7 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 0, 11]
# [DEBUG] played card value:  7
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 25 total: 26 res: False
# RL Agent 7633 draws ♡7 from the played deck.
# RL Agent 7633 puts ♡7 on the table at 2. row, 2. place
# ♤0 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 32:
# StupidM$-DOS 3.6 draws ♤0 from the played deck.
# StupidM$-DOS 3.6 puts ♤0 on the table at 0. row, 1. place
# ♧5 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 7, 11]
# [DEBUG] played card value:  5
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 49 total: 50 res: False
# RL Agent 7633 draws ♧5 from the played deck.
# RL Agent 7633 puts ♧5 on the table at 2. row, 2. place
# ♡7 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 33:
# StupidM$-DOS 3.6 draws from the drawing deck.
# StupidM$-DOS 3.6 puts ♢9 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 5, 11]
# [DEBUG] played card value:  4
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 64 total: 65 res: False
# RL Agent 7633 draws ♡4 from the played deck.
# RL Agent 7633 puts ♡4 on the table at 2. row, 2. place
# ♧5 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 34:
# StupidM$-DOS 3.6 draws ♧5 from the played deck.
# StupidM$-DOS 3.6 puts ♧5 on the table at 1. row, 1. place
# ♧6 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 4, 11]
# [DEBUG] played card value:  6
# [DEBUG] Did lottery: deck_inc: 1 played_inc: 36 total: 37 res: False
# RL Agent 7633 draws ♧6 from the played deck.
# RL Agent 7633 puts ♧6 on the table at 2. row, 2. place
# ♡4 is placed on the played deck from the table by RL Agent 7633
# ------------
# Turn 35:
# StupidM$-DOS 3.6 draws ♡4 from the played deck.
# StupidM$-DOS 3.6 puts ♡4 on the table at 2. row, 3. place
# ♡10 is placed on the played deck from the table by StupidM$-DOS 3.6
# [DEBUG] table card values:  [0, 6, 11]
# [DEBUG] played card value:  10
# [DEBUG] Did lottery: deck_inc: 9 played_inc: 4 total: 13 res: True
# RL Agent 7633 draws from the drawing deck.
# RL Agent 7633 puts ♧12 on the table at 2. row, 2. place
# ♧6 is placed on the played deck from the table by RL Agent 7633
# Game over in 35 rounds!
# Scores:
# StupidM$-DOS 3.6: 46
# RL Agent 7633: 61
# Turns quartiles:
# 0.25    18.0
# 0.50    23.0
# 0.75    30.0
# 1.00    78.0
# Name: turns, dtype: object
# Stupid player winning percentage: 60.0

# %%
results
# Out:
#                      winner turns Stupid player winner
# 0         StupidIPM 701 3.6    78                 True
# 1   StupidMc Birdbucket 2.9    24                 True
# 2               RL Agent 11     8                False
# 3             RL Agent 5877    13                False
# 4             RL Agent 9025    13                False
# ..                      ...   ...                  ...
# 95    StupidZinclair XZ 3.3    20                 True
# 96  StupidKommodore K64 3.7    17                 True
# 97  StupidMc Birdbucket 3.2    47                 True
# 98            RL Agent 4363    27                False
# 99         StupidM$-DOS 3.6    35                 True
#
# [100 rows x 3 columns]
